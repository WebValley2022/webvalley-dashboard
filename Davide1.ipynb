# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import altair as alt
from datetime import datetime

#-------input------------
Stazione = "A22 (Avio)"
Anno = "2017"


#------------Calcolo--------------------
DataInizioAnno = Anno + "-01-01"
DataFineAnno = Anno + "-12-31"

dfFull = pd.read_csv('APPA data merged 1.csv', encoding='windows-1252')
dfStazione = dfFull[dfFull.Stazione == Stazione]
dfStazione = dfStazione[DataInizioAnno <= dfFull.Data]
dfStazione = dfStazione[dfFull.Data <= DataFineAnno]

dfStazione = dfStazione[dfStazione.Valore != "n.d."]
dfStazione["Valore"] = dfStazione["Valore"].astype(float)

dfStazione["Data"] = dfStazione["Data"].str.slice(stop=10)

#dfStazione['Data'] = pd.to_datetime(dfStazione['Data'])

dfStazioneDaily = dfStazione.groupby(["Data", "Inquinante"]).mean()


dfStazioneDaily = dfStazioneDaily.reset_index()


#-----------output----------------------------------
alt.Chart(dfStazioneDaily).mark_line().encode(
    x='Data',
    y='Valore',
    color='Inquinante'
    )


dfStazione.head(10)
# Out:
# /tmp/ipykernel_26500/3521174767.py:15: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /tmp/ipykernel_26500/3521174767.py:16: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#      Stazione         Inquinante        Data  Valore UnitÃ  di misura
# 0  A22 (Avio)  Biossido di Azoto  2017-01-01    54.0           Âµg/mc
# 1  A22 (Avio)  Biossido di Azoto  2017-01-01    58.0           Âµg/mc
# 2  A22 (Avio)  Biossido di Azoto  2017-01-01    54.0           Âµg/mc
# 3  A22 (Avio)  Biossido di Azoto  2017-01-01    54.0           Âµg/mc
# 4  A22 (Avio)  Biossido di Azoto  2017-01-01    50.0           Âµg/mc
# 5  A22 (Avio)  Biossido di Azoto  2017-01-01    50.0           Âµg/mc
# 6  A22 (Avio)  Biossido di Azoto  2017-01-01    51.0           Âµg/mc
# 7  A22 (Avio)  Biossido di Azoto  2017-01-01    55.0           Âµg/mc
# 8  A22 (Avio)  Biossido di Azoto  2017-01-01    54.0           Âµg/mc
# 9  A22 (Avio)  Biossido di Azoto  2017-01-01    59.0           Âµg/mc

# %%
dfStazioneDaily.dtypes
# Out:
# Stazione                    object
# Inquinante                  object
# Data                datetime64[ns]
# Valore                     float64
# UnitÃ  di misura            object
# dtype: object

# %%
#each station for a pollutant


import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import altair as alt

#-------input------------

Inquinante = "PM10"
Anno = "2019"

#------------Calcolo--------------------
DataInizioAnno = Anno + "-01-01"
DataFineAnno = Anno + "-12-31"

dfFull = pd.read_csv('APPA data merged 1.csv', encoding='windows-1252')
dfInquinante = dfFull[dfFull.Inquinante == Inquinante]
dfInquinante = dfInquinante[DataInizioAnno <= dfFull.Data]
dfInquinante = dfInquinante[dfFull.Data <= DataFineAnno]

dfInquinante = dfInquinante[dfInquinante.Valore != "n.d."]
dfInquinante["Valore"] = dfInquinante["Valore"].astype(float)
dfInquinante["Data"] = dfInquinante["Data"].str.slice(stop=10)


dfInquinanteDaily = dfInquinante.groupby(["Data", "Stazione"]).mean()

dfInquinanteDaily = dfInquinanteDaily.reset_index()


#-----------output----------------------------------

alt.Chart(dfInquinanteDaily).mark_line().encode(
    x='Data',
    y='Valore',
    color='Stazione'
    )

# %%
from matplotlib import scale
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from statsmodels.tsa.seasonal import DecomposeResult, seasonal_decompose
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose

#-------------------------------------INPUT------------------------------------------------

#Inquinante = "Biossido di Azoto"
Inquinante = "PM10"
#Inquinante = "PM2.5"
#Inquinante = "Ossido di Carbonio"
#Inquinante = "Biossido Zolfo"
#Inquinante = "Ozono"

Anno = "2017"

#Stazione = "Parco S. Chiara"
#Stazione = "A22 (Avio)"
#Stazione = "Borgo Valsugana"
#Stazione = "Monte Gaza"
#Stazione = "Piana Rotaliana"
#Stazione = "Riva del Garda"
#Stazione = "Rovereto"
Stazione = "Via Bolzano"

#---------------------------------------CALCOLO------------------------------------------------
def plot_seasonal_decompose(result:DecomposeResult, dates:pd.Series=None, title:str=("Seasonal Decomposition " + Inquinante + " - " + Stazione)):
    x_values = dates if dates is not None else np.arange(len(result.observed))
    return (
        make_subplots(
            rows=4,
            cols=1,
            subplot_titles=["Observed", "Trend", "Seasonal", "Residuals"],
        )
        .add_trace(
            go.Scatter(x=x_values, y=result.observed, mode="lines", name='Observed'),
            row=1,
            col=1,
        )
        .add_trace(
            go.Scatter(x=x_values, y=result.trend, mode="lines", name='Trend'),
            row=2,
            col=1,
        )
        .add_trace(
            go.Scatter(x=x_values, y=result.seasonal, mode="lines", name='Seasonal'),
            row=3,
            col=1,
        )
        .add_trace(
            go.Scatter(x=x_values, y=result.resid, mode="lines", name='Residual'),
            row=4,
            col=1
        )
        .update_layout(
            height=900, title=f'<b>{title}</b>', margin={'t':100}, title_x=0.5, showlegend=False
        )
    )


DataInizioAnno = Anno + "-01-01"
DataFineAnno = Anno + "-12-31"


dfFull = pd.read_csv('APPA data merged 1.csv', encoding='windows-1252')
dfInquinante = dfFull[dfFull.Inquinante == Inquinante]
dfInquinante = dfInquinante[dfInquinante.Stazione == Stazione]
#dfInquinante = dfInquinante[DataInizioAnno <= dfFull.Data]                             #For only one year
#dfInquinante = dfInquinante[dfFull.Data <= DataFineAnno]

dfInquinante = dfInquinante[dfInquinante.Valore != "n.d."]
dfInquinante["Valore"] = dfInquinante["Valore"].astype(float)
dfInquinante["Data"] = dfInquinante["Data"].str.slice(stop=10)

dfInquinanteDaily = dfInquinante.groupby(["Data", "Stazione"]).mean()
dfInquinanteDaily = dfInquinanteDaily.reset_index()


decomposition = seasonal_decompose(dfInquinanteDaily['Valore'], model='additive', period=365)
fig = plot_seasonal_decompose(decomposition, dates=dfInquinanteDaily['Data'])

#-----------------------------------------------OUTPUT--------------------------------------------------------------------------------------

fig.show()

# %%
#each pollutant in an year of a station

from calendar import month
from re import X
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import altair as alt

#-------input------------
Stazione = "A22 (Avio)"
Anno = "2017"


#------------Calcolo--------------------
DataInizioAnno = Anno + "-01-01"
DataFineAnno = Anno + "-12-31"

dfFull = pd.read_csv('APPA data merged 1.csv', encoding='windows-1252')
dfStazione = dfFull[dfFull.Stazione == Stazione]
dfStazione = dfStazione[DataInizioAnno <= dfFull.Data]
dfStazione = dfStazione[dfFull.Data <= DataFineAnno]

dfStazione = dfStazione[dfStazione.Valore != "n.d."]
dfStazione["Valore"] = dfStazione["Valore"].astype(float)
dfStazione["Data"] = dfStazione["Data"].str.slice(stop=10)

dfStazioneDaily = dfStazione.groupby(["Data", "Inquinante"]).mean()

dfStazioneDaily = dfStazioneDaily.reset_index()


#-----------output----------------------------------
chart = alt.Chart(dfStazioneDaily).mark_line().encode(
    x='Data',
    y='Valore',
    color='Inquinante',
    bin=alt.Bin(maxbins=20)
    )


nearest = alt.selection(type='single', nearest=True, on='mouseover',
                        fields=['Data'], empty='none')

line = alt.Chart(dfStazioneDaily).mark_line(interpolate='basis').encode(
    x='Data',
    y='Valore',
    color='Inquinante',
    
)

selectors = alt.Chart(dfStazioneDaily).mark_point().encode(
    x='Data',
    opacity=alt.value(0)
).add_selection(
    nearest
)

points = line.mark_point().encode(
    opacity=alt.condition(nearest, alt.value(1), alt.value(0))
)

text = line.mark_text(align='left', dx=5, dy=-5).encode(
    text=alt.condition(nearest, 'Valore', alt.value(' '))
)

rules = alt.Chart(dfStazioneDaily).mark_rule(color='gray').encode(
    x='Data'
).transform_filter(
    nearest
)

alt.layer(
    line, selectors, points, rules, text
).properties(
    width=600, height=300

)
# Out:
# /tmp/ipykernel_44809/2780572498.py:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfStazione = dfStazione[DataInizioAnno <= dfFull.Data]
# /tmp/ipykernel_44809/2780572498.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfStazione = dfStazione[dfFull.Data <= DataFineAnno]
# alt.LayerChart(...)

# %%
AsseX[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/davide/Desktop/Git/webvalley-dashboard/Davide1.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/davide/Desktop/Git/webvalley-dashboard/Davide1.ipynb#ch0000006?line=0'>1</a> AsseX[3]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 3

# %%
print(AsseX)
# Out:
#           Stazione         Inquinante       Data  Valore UnitÃ  di misura
# 0       A22 (Avio)  Biossido di Azoto 2017-01-01    54.0           Âµg/mc
# 1       A22 (Avio)  Biossido di Azoto 2017-01-01    58.0           Âµg/mc
# 2       A22 (Avio)  Biossido di Azoto 2017-01-01    54.0           Âµg/mc
# 3       A22 (Avio)  Biossido di Azoto 2017-01-01    54.0           Âµg/mc
# 4       A22 (Avio)  Biossido di Azoto 2017-01-01    50.0           Âµg/mc
# ...            ...                ...        ...     ...              ...
# 102941  A22 (Avio)               PM10 2017-12-30     9.0           Âµg/mc
# 102942  A22 (Avio)               PM10 2017-12-30    32.0           Âµg/mc
# 102943  A22 (Avio)               PM10 2017-12-30    33.0           Âµg/mc
# 102944  A22 (Avio)               PM10 2017-12-30    33.0           Âµg/mc
# 102945  A22 (Avio)               PM10 2017-12-30    26.0           Âµg/mc
#
# [26013 rows x 5 columns]

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import altair as alt

dfFBK1 = pd.read_csv('appa_hr_crop_withCreated.csv', encoding='windows-1252')
dfFBK1.head(10)
# Out:
#                   Time         ZnOR_1         ZnOR_2       LaFeO3_1  \
# 0  2021-01-14 00:00:00  868298.139714  868298.139714  643990.633333
# 1  2021-01-14 01:00:00  959319.183333  959319.183333  650879.083333
# 2  2021-01-14 02:00:00  947694.496425  947694.496425  651594.152542
# 3  2021-01-14 03:00:00  953984.236589  953984.236589  653244.866667
# 4  2021-01-14 04:00:00  988029.291276  988029.291276  651583.400000
# 5  2021-01-14 05:00:00  957350.342448  957350.342448  657815.316667
# 6  2021-01-14 06:00:00  945211.972526  945211.972526  666222.600000
# 7  2021-01-14 07:00:00  956937.302995  956937.302995  672136.016667
# 8  2021-01-14 08:00:00  928747.246615  928747.246615  680069.550000
# 9  2021-01-14 09:00:00  916677.359245  916677.359245  689856.716667
#
#         LaFeO3_2         WO3_1         WO3_2  ZnOR_heatR_1  ZnOR_heatR_2  \
# 0  511907.200000  8.852432e+05  1.350952e+06    102.151667     99.416667
# 1  517576.116667  1.035262e+06  1.638224e+06    101.971667     99.230000
# 2  515248.949153  1.000092e+06  1.579538e+06    102.008475     99.279661
# 3  514094.800000  9.996102e+05  1.577424e+06    101.996667     99.313333
# 4  512470.350000  1.024759e+06  1.604768e+06    102.061667     99.308333
# 5  514007.900000  1.010482e+06  1.598193e+06    101.958333     99.313333
# 6  516496.850000  1.011739e+06  1.624509e+06    102.008333     99.298333
# 7  518400.716667  1.029590e+06  1.669712e+06    101.988333     99.286667
# 8  519795.666667  1.014798e+06  1.660766e+06    102.010000     99.283333
# 9  523385.883333  1.031326e+06  1.719917e+06    101.951667     99.245000
#
#    LaFeO3_heatR_1  ...   NO2   SO2   O3        CO  ZnOR_1_TimeSinceCreated  \
# 0       88.176667  ...  83.0   6.0  5.0  1.242000                      0.0
# 1       87.950000  ...  78.0   5.0  5.0  1.250667                   3600.0
# 2       87.988136  ...  78.0   6.0  4.0  1.244000                   7200.0
# 3       88.010000  ...  79.0   6.0  4.0  1.262000                  10800.0
# 4       87.995000  ...  74.0   5.0  3.0  1.190667                  14400.0
# 5       87.995000  ...  71.0   5.0  3.0  1.152000                  18000.0
# 6       87.991667  ...  65.0   3.0  3.0  1.007333                  21600.0
# 7       87.973333  ...  81.0   7.0  4.0  1.216667                  25200.0
# 8       88.001667  ...  84.0   8.0  3.0  1.191333                  28800.0
# 9       87.951667  ...  94.0  10.0  4.0  1.291333                  32400.0
#
#    ZnOR_2_TimeSinceCreated  LaFeO3_1_TimeSinceCreated  \
# 0                      0.0                        0.0
# 1                   3600.0                     3600.0
# 2                   7200.0                     7200.0
# 3                  10800.0                    10800.0
# 4                  14400.0                    14400.0
# 5                  18000.0                    18000.0
# 6                  21600.0                    21600.0
# 7                  25200.0                    25200.0
# 8                  28800.0                    28800.0
# 9                  32400.0                    32400.0
#
#    LaFeO3_2_TimeSinceCreated  WO3_1_TimeSinceCreated  WO3_2_TimeSinceCreated
# 0                        0.0                     0.0                     0.0
# 1                     3600.0                  3600.0                  3600.0
# 2                     7200.0                  7200.0                  7200.0
# 3                    10800.0                 10800.0                 10800.0
# 4                    14400.0                 14400.0                 14400.0
# 5                    18000.0                 18000.0                 18000.0
# 6                    21600.0                 21600.0                 21600.0
# 7                    25200.0                 25200.0                 25200.0
# 8                    28800.0                 28800.0                 28800.0
# 9                    32400.0                 32400.0                 32400.0
#
# [10 rows x 34 columns]

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import altair as alt

dfFBK1 = pd.read_csv('appa_hr_crop_withCreated.csv', encoding='windows-1252')
dfFBK1.head(10)
dfFBK1.drop(dfFBK1.columns[[]])
dfFBK1.head(1)
# Out:
#                         Time      LaFeO3_1      LaFeO3_2         STN_1  \
# 0  2021-01-13 10:00:00+00:00  3.293993e+07  4.579655e+07  2.323119e+08
#
#           STN_2  LaFeO3_heatR_1  LaFeO3_heatR_2  STN_heatR_1  STN_heatR_2  \
# 0  2.264656e+08       77.171739       76.676087        85.05    83.717391
#
#    LaFeO3_heatV_1  ...  STN_heatV_1  STN_heatV_2  Temperature  \
# 0        2.153696  ...     2.745652     2.722826    30.823913
#
#    Relative_Humidity    Pressure          VOC  LaFeO3_1_TimeSinceCreated  \
# 0          16.413043  994.056522  1381.336739                      36000
#
#    LaFeO3_2_TimeSinceCreated  STN_1_TimeSinceCreated  STN_2_TimeSinceCreated
# 0                      36000                   36000                   36000
#
# [1 rows x 21 columns]

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import altair as alt

dfFBK1 = pd.read_csv('FBK data/appa1_new.csv', encoding='windows-1252')
dfFBK1.head(10)

dfFBK1 = dfFBK1[dfFBK1.signal_res != "n.d."]
dfFBK1["signal_res"] = dfFBK1["signal_res"].astype(float)
dfFBK1["heater_res"] = dfFBK1["heater_res"].astype(float)
dfFBK1["heater_V"] = dfFBK1["heater_V"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)
dfFBK1["RH"] = dfFBK1["RH"].astype(float)
dfFBK1["P"] = dfFBK1["P"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)

#dfStazione["Data"] = dfStazione["Data"].str.slice(stop=10)
#dfStazione['Data'] = pd.to_datetime(dfStazione['Data'])
#dfStazioneDaily = dfStazione.groupby(["Data", "Inquinante"]).mean()

dfFBK1 = dfFBK1.drop(dfFBK1.columns[8:13], axis=1)

dfStazioneDaily = dfStazioneDaily.reset_index()


#-----------output----------------------------------
alt.Chart(dfStazioneDaily).mark_line().encode(
    x='Data',
    y='Valore',
    color='Inquinante'
    )
# Out:
#                     ts sensing_,material  signal_res  heater_res  heater_V  \
# 0  2021-01-13 00:00:00              ZnOR         NaN         NaN       NaN
# 1  2021-01-13 00:00:00              ZnOR         NaN         NaN       NaN
# 2  2021-01-13 00:00:00            LaFeO3         NaN         NaN       NaN
# 3  2021-01-13 00:00:00            LaFeO3         NaN         NaN       NaN
# 4  2021-01-13 00:00:00               WO3         NaN         NaN       NaN
# 5  2021-01-13 00:00:00               WO3         NaN         NaN       NaN
# 6  2021-01-13 00:00:00               ZnO         NaN         NaN       NaN
# 7  2021-01-13 00:00:00               ZnO         NaN         NaN       NaN
# 8  2021-01-13 01:00:00              ZnOR         NaN         NaN       NaN
# 9  2021-01-13 01:00:00              ZnOR         NaN         NaN       NaN
#
#     T  RH   P  time_cos  time_sin  date_cos  date_sin     Y              age
# 0 NaN NaN NaN  0.261799  0.000000  0.282902  0.440593  2021  0 days 00:00:00
# 1 NaN NaN NaN  0.261799  0.000000  0.282902  0.440593  2021  0 days 00:00:00
# 2 NaN NaN NaN  0.261799  0.000000  0.282902  0.440593  2021  0 days 00:00:00
# 3 NaN NaN NaN  0.261799  0.000000  0.282902  0.440593  2021  0 days 00:00:00
# 4 NaN NaN NaN  0.261799  0.000000  0.282902  0.440593  2021  0 days 00:00:00
# 5 NaN NaN NaN  0.261799  0.000000  0.282902  0.440593  2021  0 days 00:00:00
# 6 NaN NaN NaN  0.261799  0.000000  0.282902  0.440593  2021  0 days 00:00:00
# 7 NaN NaN NaN  0.261799  0.000000  0.282902  0.440593  2021  0 days 00:00:00
# 8 NaN NaN NaN  0.141451  0.220297  0.282902  0.440593  2021  0 days 01:00:00
# 9 NaN NaN NaN  0.141451  0.220297  0.282902  0.440593  2021  0 days 01:00:00

# %%
from cmath import nan
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import altair as alt

dfFBK1 = pd.read_csv('FBK data/appa1_new.csv', encoding='windows-1252')
dfFBK1 = dfFBK1.dropna()
dfFBK1=dfFBK1.drop(dfFBK1.columns[[8,9,10,11,12,13]], axis=1)

dfFBK1["signal_res"] = dfFBK1["signal_res"].astype(float)
dfFBK1["heater_res"] = dfFBK1["heater_res"].astype(float)
dfFBK1["heater_V"] = dfFBK1["heater_V"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)
dfFBK1["RH"] = dfFBK1["RH"].astype(float)
dfFBK1["P"] = dfFBK1["P"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)

dfFBK1.reset_index()

#dfStazione["Data"] = dfStazione["Data"].str.slice(stop=10)
#dfStazione['Data'] = pd.to_datetime(dfStazione['Data'])
#dfStazioneDaily = dfStazione.groupby(["Data", "Inquinante"]).mean()

dfFBK1.head(10)
# Out:
#                      ts sensing_,material    signal_res  heater_res  heater_V  \
# 64  2021-01-13 08:00:00              ZnOR  7.513813e+07   67.050000  1.431667
# 65  2021-01-13 08:00:00              ZnOR  7.495123e+07   66.125000  1.475833
# 66  2021-01-13 08:00:00            LaFeO3  7.472385e+07   70.991667  1.843333
# 67  2021-01-13 08:00:00            LaFeO3  2.713244e+07   69.975000  1.802500
# 68  2021-01-13 08:00:00               WO3  4.990000e+08   64.950000  1.730000
# 69  2021-01-13 08:00:00               WO3  4.720233e+07   67.308333  1.640000
# 70  2021-01-13 08:00:00               ZnO  3.382437e+08   69.825000  1.774167
# 71  2021-01-13 08:00:00               ZnO  3.398054e+08   68.541667  1.751667
# 72  2021-01-13 09:00:00              ZnOR  1.229693e+05  100.600000  3.954423
# 73  2021-01-13 09:00:00              ZnOR  1.594143e+05   98.575000  3.935385
#
#             T         RH           P
# 64  26.691667  22.616667  991.958333
# 65  26.691667  22.616667  991.958333
# 66  26.691667  22.616667  991.958333
# 67  26.691667  22.616667  991.958333
# 68  26.691667  22.616667  991.958333
# 69  26.691667  22.616667  991.958333
# 70  26.691667  22.616667  991.958333
# 71  26.691667  22.616667  991.958333
# 72  40.938462  11.401923  991.523077
# 73  40.938462  11.401923  991.523077

# %%
from cmath import nan
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import altair as alt

dfFBK1 = pd.read_csv('FBK data/appa1_new.csv', encoding='windows-1252')
dfFBK1 = dfFBK1.dropna()
dfFBK1=dfFBK1.drop(dfFBK1.columns[[8,9,10,11,12,13]], axis=1)
dfFBK1 = dfFBK1.drop_duplicates(['sensing_,material','ts'])
dfFBK1[['Data','Ora']]=dfFBK1.ts.str.split(' ',expand=True)

dfFBK1["signal_res"] = dfFBK1["signal_res"].astype(float)
dfFBK1["heater_res"] = dfFBK1["heater_res"].astype(float)
dfFBK1["heater_V"] = dfFBK1["heater_V"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)
dfFBK1["RH"] = dfFBK1["RH"].astype(float)
dfFBK1["P"] = dfFBK1["P"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)

dfFBK1ResV = dfFBK1.drop(dfFBK1.columns[[5,6,7]], axis=1)
dfFBK1TPH = dfFBK1.drop(dfFBK1.columns[[2,3,4]], axis=1)


print(dfFBK1)
dfFBK1.head(10)
# Out:
#                          ts sensing_,material    signal_res  heater_res  \
# 64      2021-01-13 08:00:00              ZnOR  7.513813e+07   67.050000
# 66      2021-01-13 08:00:00            LaFeO3  7.472385e+07   70.991667
# 68      2021-01-13 08:00:00               WO3  4.990000e+08   64.950000
# 70      2021-01-13 08:00:00               ZnO  3.382437e+08   69.825000
# 72      2021-01-13 09:00:00              ZnOR  1.229693e+05  100.600000
# ...                     ...               ...           ...         ...
# 107248  2022-07-25 14:00:00            LaFeO3  1.163636e+07  500.000000
# 107250  2022-07-25 14:00:00               WO3  3.269738e+07  135.350000
# 107252  2022-07-25 14:00:00              ZnOR  4.990000e+08  128.450000
# 107254  2022-07-25 14:00:00            SmFeO3  3.208780e+07  103.800000
# 107255  2022-07-25 14:00:00               STN  2.867246e+08  108.800000
#
#         heater_V          T         RH           P        Data       Ora
# 64      1.431667  26.691667  22.616667  991.958333  2021-01-13  08:00:00
# 66      1.843333  26.691667  22.616667  991.958333  2021-01-13  08:00:00
# 68      1.730000  26.691667  22.616667  991.958333  2021-01-13  08:00:00
# 70      1.774167  26.691667  22.616667  991.958333  2021-01-13  08:00:00
# 72      3.954423  40.938462  11.401923  991.523077  2021-01-13  09:00:00
# ...          ...        ...        ...         ...         ...       ...
# 107248  3.910000  41.850000  19.950000  985.550000  2022-07-25  14:00:00
# 107250  2.390000  41.850000  19.950000  985.550000  2022-07-25  14:00:00
# 107252  3.890000  41.850000  19.950000  985.550000  2022-07-25  14:00:00
# 107254  3.950000  41.850000  19.950000  985.550000  2022-07-25  14:00:00
# 107255  4.330000  41.850000  19.950000  985.550000  2022-07-25  14:00:00
#
# [62962 rows x 10 columns]
#                      ts sensing_,material    signal_res  heater_res  heater_V  \
# 64  2021-01-13 08:00:00              ZnOR  7.513813e+07   67.050000  1.431667
# 66  2021-01-13 08:00:00            LaFeO3  7.472385e+07   70.991667  1.843333
# 68  2021-01-13 08:00:00               WO3  4.990000e+08   64.950000  1.730000
# 70  2021-01-13 08:00:00               ZnO  3.382437e+08   69.825000  1.774167
# 72  2021-01-13 09:00:00              ZnOR  1.229693e+05  100.600000  3.954423
# 74  2021-01-13 09:00:00            LaFeO3  1.030804e+07   87.063462  2.953077
# 76  2021-01-13 09:00:00               WO3  2.031169e+08   38.569231  3.950577
# 78  2021-01-13 09:00:00               ZnO  2.964639e+07  106.951923  4.470769
# 80  2021-01-13 10:00:00              ZnOR  1.667689e+05  101.523333  3.996333
# 82  2021-01-13 10:00:00            LaFeO3  6.107479e+05   87.981667  3.004167
#
#             T         RH           P        Data       Ora
# 64  26.691667  22.616667  991.958333  2021-01-13  08:00:00
# 66  26.691667  22.616667  991.958333  2021-01-13  08:00:00
# 68  26.691667  22.616667  991.958333  2021-01-13  08:00:00
# 70  26.691667  22.616667  991.958333  2021-01-13  08:00:00
# 72  40.938462  11.401923  991.523077  2021-01-13  09:00:00
# 74  40.938462  11.401923  991.523077  2021-01-13  09:00:00
# 76  40.938462  11.401923  991.523077  2021-01-13  09:00:00
# 78  40.938462  11.401923  991.523077  2021-01-13  09:00:00
# 80  46.071667   5.108333  990.721667  2021-01-13  10:00:00
# 82  46.071667   5.108333  990.721667  2021-01-13  10:00:00

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import altair as alt


#------------Calcolo--------------------

dfFBK1 = pd.read_csv('FBK data/appa1_new.csv', encoding='windows-1252')

dfFBK1 = dfFBK1.dropna()
dfFBK1=dfFBK1.drop(dfFBK1.columns[[8,9,10,11,12,13]], axis=1)

dfFBK1["signal_res"] = dfFBK1["signal_res"].astype(float)
dfFBK1["heater_res"] = dfFBK1["heater_res"].astype(float)
dfFBK1["heater_V"] = dfFBK1["heater_V"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)
dfFBK1["RH"] = dfFBK1["RH"].astype(float)
dfFBK1["P"] = dfFBK1["P"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)

dfFBK1 = dfFBK1.drop_duplicates(['sensing_,material','ts'])
dfFBK1[['Data','Ora']]=dfFBK1.ts.str.split(' ',expand=True)


dfFBK1ResV = dfFBK1.drop(dfFBK1.columns[[5,6,7]], axis=1)
#dfFBK1TPH = dfFBK1.drop(dfFBK1.columns[[2,3,4]], axis=1)
#dfFBK1.head(10)
dfFBK1ResV = dfFBK1ResV.groupby(["Data", "sensing_,material"]).mean()

dfFBK1ResV = dfFBK1ResV.reset_index()


#-----------output----------------------------------
dfFBK1ResV['Data'] = pd.to_datetime(dfFBK1ResV['Data'])

alt.Chart(dfFBK1ResV).mark_line().encode(
    x='Data',
    y='heater_V',
    color='sensing_,material'
    )
# Out:
# alt.Chart(...)

# %%
from calendar import month
from re import X
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import altair as alt

#-------input------------
Anno = "2022"
Mese = "06"
Giorno = 20

GiornoFine = Giorno + 3

#------------Calcolo--------------------
dfFBK1 = pd.read_csv('FBK data/appa1_new.csv', encoding='windows-1252')

#DataInizioAnno = Anno + "-" + Mese + "-" + str(Giorno)
#DataFineAnno = Anno + "-" + Mese + "-" + str(GiornoFine)



dfFBK1 = dfFBK1.dropna()
dfFBK1=dfFBK1.drop(dfFBK1.columns[[8,9,10,11,12,13]], axis=1)
dfFBK1["signal_res"] = dfFBK1["signal_res"].astype(float)
dfFBK1["heater_res"] = dfFBK1["heater_res"].astype(float)
dfFBK1["heater_V"] = dfFBK1["heater_V"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)
dfFBK1["RH"] = dfFBK1["RH"].astype(float)
dfFBK1["P"] = dfFBK1["P"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)

dfFBK1 = dfFBK1.drop_duplicates(['sensing_,material','ts'])
dfFBK1[['Data','Ora']]=dfFBK1.ts.str.split(' ',expand=True)

dfFBK1
# Out:
#                          ts sensing_,material    signal_res  heater_res  \
# 64      2021-01-13 08:00:00              ZnOR  7.513813e+07   67.050000
# 66      2021-01-13 08:00:00            LaFeO3  7.472385e+07   70.991667
# 68      2021-01-13 08:00:00               WO3  4.990000e+08   64.950000
# 70      2021-01-13 08:00:00               ZnO  3.382437e+08   69.825000
# 72      2021-01-13 09:00:00              ZnOR  1.229693e+05  100.600000
# ...                     ...               ...           ...         ...
# 107248  2022-07-25 14:00:00            LaFeO3  1.163636e+07  500.000000
# 107250  2022-07-25 14:00:00               WO3  3.269738e+07  135.350000
# 107252  2022-07-25 14:00:00              ZnOR  4.990000e+08  128.450000
# 107254  2022-07-25 14:00:00            SmFeO3  3.208780e+07  103.800000
# 107255  2022-07-25 14:00:00               STN  2.867246e+08  108.800000
#
#         heater_V          T         RH           P        Data       Ora
# 64      1.431667  26.691667  22.616667  991.958333  2021-01-13  08:00:00
# 66      1.843333  26.691667  22.616667  991.958333  2021-01-13  08:00:00
# 68      1.730000  26.691667  22.616667  991.958333  2021-01-13  08:00:00
# 70      1.774167  26.691667  22.616667  991.958333  2021-01-13  08:00:00
# 72      3.954423  40.938462  11.401923  991.523077  2021-01-13  09:00:00
# ...          ...        ...        ...         ...         ...       ...
# 107248  3.910000  41.850000  19.950000  985.550000  2022-07-25  14:00:00
# 107250  2.390000  41.850000  19.950000  985.550000  2022-07-25  14:00:00
# 107252  3.890000  41.850000  19.950000  985.550000  2022-07-25  14:00:00
# 107254  3.950000  41.850000  19.950000  985.550000  2022-07-25  14:00:00
# 107255  4.330000  41.850000  19.950000  985.550000  2022-07-25  14:00:00
#
# [62962 rows x 10 columns]

# %%
#dfFBK1 = dfFBK1[DataInizioAnno <= dfFBK1.Data]
#dfFBK1 = dfFBK1[dfFBK1.Data <= DataFineAnno]

dfFBK1ResV = dfFBK1.drop(dfFBK1.columns[[5,6,7]], axis=1)
#dfFBK1TPH = dfFBK1.drop(dfFBK1.columns[[2,3,4]], axis=1)
#dfFBK1.head(10)
dfFBK1ResV = dfFBK1ResV.groupby(["Data", "sensing_,material"]).mean()
dfFBK1['ts'] = pd.to_datetime(dfFBK1['ts'])

dfFBK1ResV = dfFBK1ResV.reset_index()


#-----------output----------------------------------
chart = alt.Chart(dfFBK1ResV).mark_line().encode(
    x="ts:T",
    y='heater_res',
    color='sensing_,material',
    bin=alt.Bin(maxbins=20)
    )


nearest = alt.selection(type='single', nearest=True, on='mouseover',
                        fields=['Data'], empty='none')

line = alt.Chart(dfFBK1ResV).mark_line(interpolate='basis').encode(
    x = 'ts:T',
    y='heater_res',
    color='sensing_,material',
    
)

selectors = alt.Chart(dfFBK1ResV).mark_point().encode(
    x='ts:T',
    opacity=alt.value(0)
).add_selection(
    nearest
)

points = line.mark_point().encode(
    opacity=alt.condition(nearest, alt.value(1), alt.value(0))
)

text = line.mark_text(align='left', dx=5, dy=-5).encode(
    text=alt.condition(nearest, 'heater_res', alt.value(' '))
)

rules = alt.Chart(dfFBK1ResV).mark_rule(color='gray').encode(
    x='ts:T'
).transform_filter(
    nearest
)

alt.layer(
    line, selectors, points, rules, text
).properties(
    width=1000, height=500

)

dfFBK1ResV

# %%
from calendar import month
from re import X
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import altair as alt

#-------input------------
#Anno = "2022"
#Mese = "06"
#Giorno = 20

#GiornoFine = Giorno + 3

#------------Calcolo--------------------
dfFBK1 = pd.read_csv('FBK data/appa1_new.csv', encoding='windows-1252')
dfFBK1.ts = pd.to_datetime(dfFBK1.ts)

#DataInizioAnno = Anno + "-" + Mese + "-" + str(Giorno)
#DataFineAnno = Anno + "-" + Mese + "-" + str(GiornoFine)



dfFBK1 = dfFBK1.dropna()
dfFBK1=dfFBK1.drop(dfFBK1.columns[[8,9,10,11,12,13]], axis=1)
dfFBK1["signal_res"] = dfFBK1["signal_res"].astype(float)
dfFBK1["heater_res"] = dfFBK1["heater_res"].astype(float)
dfFBK1["heater_V"] = dfFBK1["heater_V"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)
dfFBK1["RH"] = dfFBK1["RH"].astype(float)
dfFBK1["P"] = dfFBK1["P"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)

dfFBK1 = dfFBK1.drop_duplicates(['sensing_,material','ts'])
dfFBK1['Data'] = pd.to_datetime(dfFBK1.ts.dt.date)
dfFBK1['Ora'] = str(dfFBK1.ts.dt.time)
dfFBK1.dtypes
# Out:
# ts                   datetime64[ns]
# sensing_,material            object
# signal_res                  float64
# heater_res                  float64
# heater_V                    float64
# T                           float64
# RH                          float64
# P                           float64
# Data                         object
# Ora                          object
# dtype: object

# %%
# dfFBK1[['Data','Ora']]=dfFBK1.ts.str.split(' ',expand=True)

#dfFBK1 = dfFBK1[DataInizioAnno <= dfFBK1.Data]
#dfFBK1 = dfFBK1[dfFBK1.Data <= DataFineAnno]

#dfFBK1ResV = dfFBK1.drop(dfFBK1.columns[[5,6,7]], axis=1)
dfFBK1TPH = dfFBK1.drop(dfFBK1.columns[[2,3,4]], axis=1)
#dfFBK1.head(10)
dfFBK1TPH = dfFBK1TPH.groupby(["Data", "sensing_,material"]).mean()
dfFBK1TPH = dfFBK1TPH.reset_index()
print(dfFBK1TPH)

dfFBK1TPH["Data"] = pd.to_datetime(dfFBK1TPH["Data"])
dfFBK1TPH = dfFBK1TPH.reset_index()


#-----------output----------------------------------
chart = alt.Chart(dfFBK1TPH).mark_line().encode(
    x="Data",
    y='T',
    color='sensing_,material',
    bin=alt.Bin(maxbins=20)
    )


nearest = alt.selection(type='single', nearest=True, on='mouseover',
                        fields=['Data'], empty='none')

line = alt.Chart(dfFBK1TPH).mark_line(interpolate='basis').encode(
    x = 'Data',
    y='T',
    color='sensing_,material',
    
)

selectors = alt.Chart(dfFBK1TPH).mark_point().encode(
    x='Data',
    opacity=alt.value(0)
).add_selection(
    nearest
)

points = line.mark_point().encode(
    opacity=alt.condition(nearest, alt.value(1), alt.value(0))
)

text = line.mark_text(align='left', dx=5, dy=-5).encode(
    text=alt.condition(nearest, 'T', alt.value(' '))
)

rules = alt.Chart(dfFBK1TPH).mark_rule(color='gray').encode(
    x='Data'
).transform_filter(
    nearest
)

alt.layer(
    line, selectors, points, rules, text
).properties(
    width=1000, height=500

)
# Out:
#             Data sensing_,material          T         RH           P
# 0     2021-01-13            LaFeO3  45.643198   5.945588  990.092766
# 1     2021-01-13               WO3  45.643198   5.945588  990.092766
# 2     2021-01-13               ZnO  45.643198   5.945588  990.092766
# 3     2021-01-13              ZnOR  45.643198   5.945588  990.092766
# 4     2021-01-14            LaFeO3  44.439548   5.186019  987.288144
# ...          ...               ...        ...        ...         ...
# 2622  2022-07-25            LaFeO3  36.014514  29.599217  990.035947
# 2623  2022-07-25               STN  36.014514  29.599217  990.035947
# 2624  2022-07-25            SmFeO3  36.014514  29.599217  990.035947
# 2625  2022-07-25               WO3  36.014514  29.599217  990.035947
# 2626  2022-07-25              ZnOR  36.014514  29.599217  990.035947
#
# [2627 rows x 5 columns]
# alt.LayerChart(...)

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from matplotlib import pyplot as plt
import seaborn as sns

#----------------INPUT---------------
SensingMaterial = "LaFeO3"
Anno = "2021"


#------------IMPORT---------
dfFBK1 = pd.read_csv('FBK data/appa1_new.csv', encoding='windows-1252')
dfFBK1.ts = pd.to_datetime(dfFBK1.ts)

#------------SETTING FILTER-------------------------
DataInizioAnno = Anno + "-01-01"
DataFineAnno = Anno + "-12-31"

#SETTING UP DF
dfFBK1 = dfFBK1.dropna()
dfFBK1=dfFBK1.drop(dfFBK1.columns[[8,9,10,11,12,13]], axis=1)
dfFBK1["signal_res"] = dfFBK1["signal_res"].astype(float)
dfFBK1["heater_res"] = dfFBK1["heater_res"].astype(float)
dfFBK1["heater_V"] = dfFBK1["heater_V"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)
dfFBK1["RH"] = dfFBK1["RH"].astype(float)
dfFBK1["P"] = dfFBK1["P"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)

dfFBK1 = dfFBK1.drop_duplicates(['sensing_,material','ts'])
dfFBK1['Data'] = pd.to_datetime(dfFBK1.ts.dt.date)
dfFBK1['Ora'] = str(dfFBK1.ts.dt.time)

dfFBK1TPH = dfFBK1.drop(dfFBK1.columns[[2,3,4]], axis=1)
dfFBK1TPH = dfFBK1TPH.groupby(["Data", "sensing_,material"]).mean()
dfFBK1TPH = dfFBK1TPH.reset_index()

#dfFBK1Sens = dfFBK1TPH[dfFBK1TPH["sensing_,material"] == SensingMaterial]

dfFBK1TPH = dfFBK1TPH[DataInizioAnno <= dfFBK1TPH.Data]
dfFBK1TPH = dfFBK1TPH[dfFBK1TPH.Data <= DataFineAnno]

dfFBK1TPH["Data"] = pd.to_datetime(dfFBK1TPH["Data"])
dfFBK1Sens = dfFBK1TPH.reset_index()

fig = px.line(dfFBK1Sens, x='Data', y=["T", "RH", "P"])
fig.show()

# %%
#-----------------------------PLOTTING Temperature - Pressure - Humidity -------------- middle-right plot---------------------------------------------------------



import pandas as pd
import numpy as np
import plotly.express as px
from matplotlib import pyplot as plt
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go

#----------------INPUT---------------
SensingMaterial = "LaFeO3"
Anno = "2021"
plot_width = 800
plot_height = 400


#------------IMPORT---------
dfFBK1 = pd.read_csv('FBK data/appa1_new.csv', encoding='windows-1252')
dfFBK1.ts = pd.to_datetime(dfFBK1.ts)

#------------SETTING FILTER-------------------------
DataInizioAnno = Anno + "-01-01" #optional
DataFineAnno = Anno + "-12-31"

#SETTING UP DF
dfFBK1 = dfFBK1.dropna()
dfFBK1=dfFBK1.drop(dfFBK1.columns[[8,9,10,11,12,13]], axis=1)
dfFBK1["signal_res"] = dfFBK1["signal_res"].astype(float)
dfFBK1["heater_res"] = dfFBK1["heater_res"].astype(float)
dfFBK1["heater_V"] = dfFBK1["heater_V"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)
dfFBK1["RH"] = dfFBK1["RH"].astype(float)
dfFBK1["P"] = dfFBK1["P"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)

dfFBK1 = dfFBK1.drop_duplicates(['sensing_,material','ts'])
dfFBK1['Data'] = pd.to_datetime(dfFBK1.ts.dt.date)
dfFBK1['Ora'] = str(dfFBK1.ts.dt.time)

dfFBK1TPH = dfFBK1.drop(dfFBK1.columns[[2,3,4]], axis=1)
dfFBK1TPH = dfFBK1TPH.groupby(["Data", "sensing_,material"]).mean()
dfFBK1TPH = dfFBK1TPH.reset_index()

dfFBK1TPH["Data"] = pd.to_datetime(dfFBK1TPH["Data"])
dfFBK1Sens = dfFBK1TPH.reset_index()

#--------------------------FILTERING STUFF -----------------------------------------
#dfFBK1Sens = dfFBK1TPH[dfFBK1TPH["sensing_,material"] == SensingMaterial]

#dfFBK1TPH = dfFBK1TPH[DataInizioAnno <= dfFBK1TPH.Data]
#dfFBK1TPH = dfFBK1TPH[dfFBK1TPH.Data <= DataFineAnno]
#----------------------------------------------------------------------------------



trace1 = go.Scatter(x=dfFBK1TPH['Data'],
                        y=dfFBK1TPH['T'],
                        name='Temperature',
                        mode='lines',
                        yaxis='y1',
                        hovertemplate="Parameter = Temperature<br>Value = %{y}<br>Date = %{x}<extra></extra>")

trace2 = go.Scatter(x=dfFBK1TPH['Data'],
                        y=dfFBK1TPH['RH'],
                        name='Humidity',
                        mode='lines',
                        yaxis='y1',
                        hovertemplate="Parameter = Humidity<br>Value = %{y}<br>Date = %{x}<extra></extra>")

trace3 = go.Scatter(x=dfFBK1TPH['Data'],
                    y=dfFBK1TPH['P'],
                    name='Pressure',
                    yaxis='y2',
                    mode = 'lines',
                    hovertemplate="Parameter = Pressure<br>Value = %{y}<br>Date = %{x}<extra></extra>"
                    )

data = [trace1, trace2, trace3]
layout = go.Layout(title='Temperature - Pressure - Humidity',
                       yaxis=dict(title='Humidity - Temperature'),
                       yaxis2=dict(title='Pressure',
                                   overlaying='y',
                                   side='right'
                                   ),
                        width= plot_width,
                        height= plot_height,
                        legend = dict(orientation="h",
                        yanchor="bottom",
                        y=1.02,
                        xanchor="right",
                        x=1)
                    )


go.Figure(data=data, layout=layout)

# %%
#-----------------------------PLOTTING Heater resistence and Voltage---------------------------------------------------------

import pandas as pd
import numpy as np
import plotly.express as px
from matplotlib import pyplot as plt
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go

#----------------INPUT---------------
SensingMaterial = "LaFeO3"
Anno = "2021"
plot_width = 800
plot_height = 400


#------------IMPORT---------
dfFBK1 = pd.read_csv('FBK data/appa1_new.csv', encoding='windows-1252')
dfFBK1.ts = pd.to_datetime(dfFBK1.ts)

#------------SETTING FILTER-------------------------
DataInizioAnno = Anno + "-01-01" #OPTIONAL
DataFineAnno = Anno + "-12-31"

#SETTING UP DF
dfFBK1 = dfFBK1.dropna()
dfFBK1=dfFBK1.drop(dfFBK1.columns[[8,9,10,11,12,13]], axis=1)
dfFBK1["signal_res"] = dfFBK1["signal_res"].astype(float)
dfFBK1["heater_res"] = dfFBK1["heater_res"].astype(float)
dfFBK1["heater_V"] = dfFBK1["heater_V"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)
dfFBK1["RH"] = dfFBK1["RH"].astype(float)
dfFBK1["P"] = dfFBK1["P"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)

dfFBK1 = dfFBK1.drop_duplicates(['sensing_,material','ts'])
dfFBK1['Data'] = pd.to_datetime(dfFBK1.ts.dt.date)
dfFBK1['Ora'] = str(dfFBK1.ts.dt.time)

dfFBK1ResV = dfFBK1.drop(dfFBK1.columns[[5,6,7]], axis=1)
dfFBK1ResV = dfFBK1ResV.groupby(["Data", "sensing_,material"]).mean()
dfFBK1ResV = dfFBK1ResV.reset_index()

dfFBK1ResV["Data"] = pd.to_datetime(dfFBK1ResV["Data"])
dfFBK1Sens = dfFBK1ResV[dfFBK1ResV["sensing_,material"] == SensingMaterial]

#--------------------------FILTERING STUFF -----------------------------------------
#dfFBK1Sens = dfFBK1TPH[dfFBK1TPH["sensing_,material"] == SensingMaterial]

#dfFBK1TPH = dfFBK1TPH[DataInizioAnno <= dfFBK1TPH.Data]
#dfFBK1TPH = dfFBK1TPH[dfFBK1TPH.Data <= DataFineAnno]
#----------------------------------------------------------------------------------

trace1 = go.Scatter(x=dfFBK1Sens['Data'],
                        y=dfFBK1Sens['heater_res'],
                        name='Resistence',
                        mode='lines',
                        yaxis='y1',
                        hovertemplate="Parameter = Resistence<br>Value = %{y}<br>Date = %{x}<extra></extra>")

trace2 = go.Scatter(x=dfFBK1Sens['Data'],
                        y=dfFBK1Sens['heater_V'],
                        name='Voltage',
                        mode='lines',
                        yaxis='y2',
                        hovertemplate="Parameter = Voltage<br>Value = %{y}<br>Date = %{x}<extra></extra>")

data = [trace1, trace2]
layout = go.Layout(title='Heater resistence and Voltage',
                       yaxis=dict(title='Humidity'),
                       yaxis2=dict(title='Voltage',
                                   overlaying='y',
                                   side='right'
                                   ),
                        width= plot_width,
                        height= plot_height,
                        legend = dict(orientation="h",
                        yanchor="bottom",
                        y=1.02,
                        xanchor="right",
                        x=1)
                    )


go.Figure(data=data, layout=layout)

# %%
#-----------------------------PLOTTING Heaters resistence and Voltage---------------------------------------------------------

import pandas as pd
import numpy as np
import plotly.express as px
from matplotlib import pyplot as plt
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go

#----------------INPUT---------------
Variable = "LaFeO3"
Anno = "2021"
plot_width = 800
plot_height = 400


#------------IMPORT---------
dfFBK1 = pd.read_csv('FBK data/appa1_new.csv', encoding='windows-1252')
dfFBK1.ts = pd.to_datetime(dfFBK1.ts)

#------------SETTING FILTER-------------------------
DataInizioAnno = Anno + "-01-01" #OPTIONAL
DataFineAnno = Anno + "-12-31"

#SETTING UP DF
dfFBK1 = dfFBK1.dropna()
dfFBK1=dfFBK1.drop(dfFBK1.columns[[8,9,10,11,12,13]], axis=1)
dfFBK1["signal_res"] = dfFBK1["signal_res"].astype(float)
dfFBK1["heater_res"] = dfFBK1["heater_res"].astype(float)
dfFBK1["heater_V"] = dfFBK1["heater_V"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)
dfFBK1["RH"] = dfFBK1["RH"].astype(float)
dfFBK1["P"] = dfFBK1["P"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)

dfFBK1 = dfFBK1.drop_duplicates(['sensing_,material','ts'])
dfFBK1['Data'] = pd.to_datetime(dfFBK1.ts.dt.date)
dfFBK1['Ora'] = str(dfFBK1.ts.dt.time)

dfFBK1ResV = dfFBK1.drop(dfFBK1.columns[[5,6,7]], axis=1)
dfFBK1ResV = dfFBK1ResV.groupby(["Data", "sensing_,material"]).mean()
dfFBK1ResV = dfFBK1ResV.reset_index()

dfFBK1ResV["Data"] = pd.to_datetime(dfFBK1ResV["Data"])
dfFBK1Sens = dfFBK1ResV[dfFBK1ResV["sensing_,material"] == SensingMaterial]

#--------------------------FILTERING STUFF -----------------------------------------
#dfFBK1Sens = dfFBK1TPH[dfFBK1TPH["sensing_,material"] == SensingMaterial]

#dfFBK1TPH = dfFBK1TPH[DataInizioAnno <= dfFBK1TPH.Data]
#dfFBK1TPH = dfFBK1TPH[dfFBK1TPH.Data <= DataFineAnno]
#----------------------------------------------------------------------------------

trace1 = go.Scatter(x=dfFBK1Sens['Data'],
                        y=dfFBK1Sens['heater_res'],
                        name='Resistence',
                        mode='lines',
                        yaxis='y1',
                        hovertemplate="Parameter = Resistence<br>Value = %{y}<br>Date = %{x}<extra></extra>")

trace2 = go.Scatter(x=dfFBK1Sens['Data'],
                        y=dfFBK1Sens['heater_V'],
                        name='Voltage',
                        mode='lines',
                        yaxis='y2',
                        hovertemplate="Parameter = Voltage<br>Value = %{y}<br>Date = %{x}<extra></extra>")

data = [trace1, trace2]
layout = go.Layout(title='Heater resistence and Voltage',
                       yaxis=dict(title='Humidity'),
                       yaxis2=dict(title='Voltage',
                                   overlaying='y',
                                   side='right'
                                   ),
                        width= plot_width,
                        height= plot_height,
                        legend = dict(orientation="h",
                        yanchor="bottom",
                        y=1.02,
                        xanchor="right",
                        x=1)
                    )


go.Figure(data=data, layout=layout)

# %%
#-----------------------------PLOTTING signal resistence---------------------big plot------------------------------------

import pandas as pd
import numpy as np
import plotly.express as px
from matplotlib import pyplot as plt
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go

#----------------INPUT---------------
SensingMaterial = "LaFeO3"
Anno = "2021"
plot_width = 800
plot_height = 400


#------------IMPORT---------
dfFBK1 = pd.read_csv('FBK data/appa1_new.csv', encoding='windows-1252')
dfFBK1.ts = pd.to_datetime(dfFBK1.ts)

#------------SETTING FILTER-------------------------
DataInizioAnno = Anno + "-01-01" #OPTIONAL
DataFineAnno = Anno + "-12-31"

#SETTING UP DF
dfFBK1 = dfFBK1.dropna()
dfFBK1=dfFBK1.drop(dfFBK1.columns[[8,9,10,11,12,13]], axis=1)
dfFBK1["signal_res"] = dfFBK1["signal_res"].astype(float)
dfFBK1["heater_res"] = dfFBK1["heater_res"].astype(float)
dfFBK1["heater_V"] = dfFBK1["heater_V"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)
dfFBK1["RH"] = dfFBK1["RH"].astype(float)
dfFBK1["P"] = dfFBK1["P"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)

dfFBK1 = dfFBK1.drop_duplicates(['sensing_,material','ts'])
dfFBK1['Data'] = pd.to_datetime(dfFBK1.ts.dt.date)
dfFBK1['Ora'] = str(dfFBK1.ts.dt.time)

dfFBK1ResV = dfFBK1.drop(dfFBK1.columns[[5,6,7]], axis=1) #drop Temperature, humidity, pressure
dfFBK1ResV = dfFBK1ResV.groupby(["Data", "sensing_,material"]).mean()
dfFBK1ResV = dfFBK1ResV.reset_index()

dfFBK1ResV["Data"] = pd.to_datetime(dfFBK1ResV["Data"])
dfFBK1ResV = dfFBK1ResV.drop(dfFBK1.columns[[3,4]], axis=1)  #1 index = Data, 2index = sensing material, 3index = signal_res, 4index = heater_res, 5index = heater_V

#dfFBK1Sens = dfFBK1ResV[dfFBK1ResV["sensing_,material"] == SensingMaterial]

#--------------------------FILTERING STUFF -----------------------------------------
#dfFBK1Sens = dfFBK1TPH[dfFBK1TPH["sensing_,material"] == SensingMaterial]

#dfFBK1TPH = dfFBK1TPH[DataInizioAnno <= dfFBK1TPH.Data]
#dfFBK1TPH = dfFBK1TPH[dfFBK1TPH.Data <= DataFineAnno]
#----------------------------------------------------------------------------------

fig = go.Figure()
for SensingMaterial, group in dfFBK1ResV.groupby("sensing_,material"):
    fig.add_trace(go.Scatter(
        x = dfFBK1ResV[
            dfFBK1ResV["sensing_,material"] == SensingMaterial
        ]["Data"],
        y = dfFBK1ResV[
            dfFBK1ResV["sensing_,material"] == SensingMaterial
        ]["signal_res"],
        name=SensingMaterial)
    )

fig.update_layout(legend_title_text = "Sensing Material")
fig.update_yaxes(title_text="Value")
fig.show()

# %%
#top-right plot-----------------------------PLOTTING heaters resistence---------------------------------------------------------

import pandas as pd
import numpy as np
import plotly.express as px
from matplotlib import pyplot as plt
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go

#----------------INPUT---------------
SensingMaterial = "LaFeO3"
Anno = "2021"
plot_width = 800
plot_height = 400


#------------IMPORT---------
dfFBK1 = pd.read_csv('FBK data/appa1_new.csv', encoding='windows-1252')
dfFBK1.ts = pd.to_datetime(dfFBK1.ts)

#------------SETTING FILTER-------------------------
DataInizioAnno = Anno + "-01-01" #OPTIONAL
DataFineAnno = Anno + "-12-31"

#SETTING UP DF
dfFBK1 = dfFBK1.dropna()
dfFBK1=dfFBK1.drop(dfFBK1.columns[[8,9,10,11,12,13]], axis=1)
dfFBK1["signal_res"] = dfFBK1["signal_res"].astype(float)
dfFBK1["heater_res"] = dfFBK1["heater_res"].astype(float)
dfFBK1["heater_V"] = dfFBK1["heater_V"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)
dfFBK1["RH"] = dfFBK1["RH"].astype(float)
dfFBK1["P"] = dfFBK1["P"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)

dfFBK1 = dfFBK1.drop_duplicates(['sensing_,material','ts'])
dfFBK1['Data'] = pd.to_datetime(dfFBK1.ts.dt.date)
dfFBK1['Ora'] = str(dfFBK1.ts.dt.time)

dfFBK1ResV = dfFBK1.drop(dfFBK1.columns[[5,6,7]], axis=1) #drop Temperature, humidity, pressure
dfFBK1ResV = dfFBK1ResV.groupby(["Data", "sensing_,material"]).mean()
dfFBK1ResV = dfFBK1ResV.reset_index()

dfFBK1ResV["Data"] = pd.to_datetime(dfFBK1ResV["Data"])
dfFBK1ResV = dfFBK1ResV.drop(dfFBK1.columns[[2,4]], axis=1)  #0 index = Data, 1index = sensing material, 2index = signal_res, 3index = heater_res, 4index = heater_V

#dfFBK1Sens = dfFBK1ResV[dfFBK1ResV["sensing_,material"] == SensingMaterial]

#--------------------------FILTERING STUFF -----------------------------------------
#dfFBK1Sens = dfFBK1TPH[dfFBK1TPH["sensing_,material"] == SensingMaterial]

#dfFBK1TPH = dfFBK1TPH[DataInizioAnno <= dfFBK1TPH.Data]
#dfFBK1TPH = dfFBK1TPH[dfFBK1TPH.Data <= DataFineAnno]
#----------------------------------------------------------------------------------

fig = go.Figure()
for SensingMaterial, group in dfFBK1ResV.groupby("sensing_,material"):
    fig.add_trace(go.Scatter(
        x = dfFBK1ResV[
            dfFBK1ResV["sensing_,material"] == SensingMaterial
        ]["Data"],
        y = dfFBK1ResV[
            dfFBK1ResV["sensing_,material"] == SensingMaterial
        ]["heater_res"],
        name=SensingMaterial)
    )

fig.update_layout(legend_title_text = "Sensing Material")
fig.update_yaxes(title_text="Value")
fig.show()

# %%
#-----------------------------PLOTTING heaters voltage--------------bottom-right plot-------------------------------------------

import pandas as pd
import numpy as np
import plotly.express as px
from matplotlib import pyplot as plt
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go

#----------------INPUT---------------
SensingMaterial = "LaFeO3"
Anno = "2021"
plot_width = 800
plot_height = 400


#------------IMPORT---------
dfFBK1 = pd.read_csv('FBK data/appa1_new.csv', encoding='windows-1252')
dfFBK1.ts = pd.to_datetime(dfFBK1.ts)

#------------SETTING FILTER-------------------------
DataInizioAnno = Anno + "-01-01" #OPTIONAL
DataFineAnno = Anno + "-12-31"

#SETTING UP DF
dfFBK1 = dfFBK1.dropna()
dfFBK1=dfFBK1.drop(dfFBK1.columns[[8,9,10,11,12,13]], axis=1)
dfFBK1["signal_res"] = dfFBK1["signal_res"].astype(float)
dfFBK1["heater_res"] = dfFBK1["heater_res"].astype(float)
dfFBK1["heater_V"] = dfFBK1["heater_V"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)
dfFBK1["RH"] = dfFBK1["RH"].astype(float)
dfFBK1["P"] = dfFBK1["P"].astype(float)
dfFBK1["T"] = dfFBK1["T"].astype(float)

dfFBK1 = dfFBK1.drop_duplicates(['sensing_,material','ts'])
dfFBK1['Data'] = pd.to_datetime(dfFBK1.ts.dt.date)
dfFBK1['Ora'] = str(dfFBK1.ts.dt.time)

dfFBK1ResV = dfFBK1.drop(dfFBK1.columns[[5,6,7]], axis=1) #drop Temperature, humidity, pressure
dfFBK1ResV = dfFBK1ResV.groupby(["Data", "sensing_,material"]).mean()
dfFBK1ResV = dfFBK1ResV.reset_index()

dfFBK1ResV["Data"] = pd.to_datetime(dfFBK1ResV["Data"])
dfFBK1ResV = dfFBK1ResV.drop(dfFBK1.columns[[2,3]], axis=1)  #0 index = Data, 1index = sensing material, 2index = signal_res, 3index = heater_res, 4index = heater_V

#dfFBK1Sens = dfFBK1ResV[dfFBK1ResV["sensing_,material"] == SensingMaterial]

#--------------------------FILTERING STUFF -----------------------------------------
#dfFBK1Sens = dfFBK1TPH[dfFBK1TPH["sensing_,material"] == SensingMaterial]

#dfFBK1TPH = dfFBK1TPH[DataInizioAnno <= dfFBK1TPH.Data]
#dfFBK1TPH = dfFBK1TPH[dfFBK1TPH.Data <= DataFineAnno]
#----------------------------------------------------------------------------------

fig = go.Figure()
for SensingMaterial, group in dfFBK1ResV.groupby("sensing_,material"):
    fig.add_trace(go.Scatter(
        x = dfFBK1ResV[
            dfFBK1ResV["sensing_,material"] == SensingMaterial
        ]["Data"],
        y = dfFBK1ResV[
            dfFBK1ResV["sensing_,material"] == SensingMaterial
        ]["heater_V"],
        name=SensingMaterial)
    )

fig.update_layout(legend_title_text = "Sensing Material")
fig.update_yaxes(title_text="Value")
fig.show()

# %%
#each pollutant in an year of a station

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import altair as alt

#-------input------------
Stazione = "A22 (Avio)"
Anno = "2017"


#------------Calcolo--------------------
DataInizioAnno = Anno + "-01-01"
DataFineAnno = Anno + "-12-31"

dfFull = pd.read_csv('APPA data merged 1.csv', encoding='windows-1252')
dfStazione = dfFull[dfFull.Stazione == Stazione]
dfStazione = dfStazione[DataInizioAnno <= dfFull.Data]
dfStazione = dfStazione[dfFull.Data <= DataFineAnno]

dfStazione = dfStazione[dfStazione.Valore != "n.d."]
dfStazione["Valore"] = dfStazione["Valore"].astype(float)

dfStazioneDaily = dfStazione.groupby(["Data", "Inquinante"]).mean()

dfStazioneDaily = dfStazioneDaily.reset_index()


#-----------output----------------------------------
alt.Chart(dfStazioneDaily).mark_line().encode(
    x='Data',
    y='Valore',
    color='Inquinante'
    )
# Out:
# /tmp/ipykernel_47710/2323029595.py:18: DtypeWarning:
#
# Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#
# /tmp/ipykernel_47710/2323029595.py:20: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /tmp/ipykernel_47710/2323029595.py:21: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# alt.Chart(...)

# %%
#each station for a pollutant


import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import altair as alt

#-------input------------

Inquinante = "PM10"
Anno = "2019"

#------------Calcolo--------------------
DataInizioAnno = Anno + "-01-01"
DataFineAnno = Anno + "-12-31"

dfFull = pd.read_csv('APPA data merged 1.csv', encoding='windows-1252')
dfInquinante = dfFull[dfFull.Inquinante == Inquinante]
dfInquinante = dfInquinante[DataInizioAnno <= dfFull.Data]
dfInquinante = dfInquinante[dfFull.Data <= DataFineAnno]

dfInquinante = dfInquinante[dfInquinante.Valore != "n.d."]
dfInquinante["Valore"] = dfInquinante["Valore"].astype(float)

dfInquinanteDaily = dfInquinante.groupby(["Data", "Stazione"]).mean()

dfInquinanteDaily = dfInquinanteDaily.reset_index()


#-----------output----------------------------------

alt.Chart(dfInquinanteDaily).mark_line().encode(
    x='Data',
    y='Valore',
    color='Stazione'
    )
# Out:
# /tmp/ipykernel_47710/2091904147.py:19: DtypeWarning:
#
# Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#
# /tmp/ipykernel_47710/2091904147.py:21: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /tmp/ipykernel_47710/2091904147.py:22: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# alt.Chart(...)

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from statsmodels.tsa.seasonal import DecomposeResult, seasonal_decompose
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose

#-------------------------------------INPUT------------------------------------------------

#Inquinante = "Biossido di Azoto"
Inquinante = "PM10"
#Inquinante = "PM2.5"
#Inquinante = "Ossido di Carbonio"
#Inquinante = "Biossido Zolfo"
#Inquinante = "Ozono"

Anno = "2017"

#Stazione = "Parco S. Chiara"
#Stazione = "A22 (Avio)"
#Stazione = "Borgo Valsugana"
#Stazione = "Monte Gaza"
#Stazione = "Piana Rotaliana"
#Stazione = "Riva del Garda"
#Stazione = "Rovereto"
Stazione = "Via Bolzano"

#---------------------------------------CALCOLO------------------------------------------------
def plot_seasonal_decompose(result:DecomposeResult, dates:pd.Series=None, title:str="Seasonal Decomposition"):
    x_values = dates if dates is not None else np.arange(len(result.observed))
    return (
        make_subplots(
            rows=4,
            cols=1,
            subplot_titles=["Observed", "Trend", "Seasonal", "Residuals"],
        )
        .add_trace(
            go.Scatter(x=x_values, y=result.observed, mode="lines", name='Observed'),
            row=1,
            col=1,
        )
        .add_trace(
            go.Scatter(x=x_values, y=result.trend, mode="lines", name='Trend'),
            row=2,
            col=1,
        )
        .add_trace(
            go.Scatter(x=x_values, y=result.seasonal, mode="lines", name='Seasonal'),
            row=3,
            col=1,
        )
        .add_trace(
            go.Scatter(x=x_values, y=result.resid, mode="lines", name='Residual'),
            row=4,
            col=1,
        )
        .update_layout(
            height=900, title=f'<b>{title}</b>', margin={'t':100}, title_x=0.5, showlegend=False
        )
    )


DataInizioAnno = Anno + "-01-01"
DataFineAnno = Anno + "-12-31"


dfFull = pd.read_csv('APPA data merged 1.csv', encoding='windows-1252')
dfInquinante = dfFull[dfFull.Inquinante == Inquinante]
dfInquinante = dfInquinante[dfInquinante.Stazione == Stazione]
#dfInquinante = dfInquinante[DataInizioAnno <= dfFull.Data]                             #For only one year
#dfInquinante = dfInquinante[dfFull.Data <= DataFineAnno]

dfInquinante = dfInquinante[dfInquinante.Valore != "n.d."]
dfInquinante["Valore"] = dfInquinante["Valore"].astype(float)

dfInquinanteDaily = dfInquinante.groupby(["Data", "Stazione"]).mean()
dfInquinanteDaily = dfInquinanteDaily.reset_index()


decomposition = seasonal_decompose(dfInquinanteDaily['Valore'], model='additive', period=366)
fig = plot_seasonal_decompose(decomposition, dates=dfInquinanteDaily['Data'])

#-----------------------------------------------OUTPUT--------------------------------------------------------------------------------------

fig.show()
# Out:
# /tmp/ipykernel_47710/2968484252.py:66: DtypeWarning:
#
# Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
#each pollutant in an year of a station

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import altair as alt

#-------input------------
Stazione = "A22 (Avio)"
Anno = "2017"


#------------Calcolo--------------------
DataInizioAnno = Anno + "-01-01"
DataFineAnno = Anno + "-12-31"

dfFull = pd.read_csv('APPA data merged 1.csv', encoding='windows-1252')
dfStazione = dfFull[dfFull.Stazione == Stazione]
dfStazione = dfStazione[DataInizioAnno <= dfFull.Data]
dfStazione = dfStazione[dfFull.Data <= DataFineAnno]

dfStazione = dfStazione[dfStazione.Valore != "n.d."]
dfStazione["Valore"] = dfStazione["Valore"].astype(float)

dfStazioneDaily = dfStazione.groupby(["Data", "Inquinante"]).mean()

dfStazioneDaily = dfStazioneDaily.reset_index()


#-----------output----------------------------------
chart = alt.Chart(dfStazioneDaily).mark_line().encode(
    x='Data',
    y='Valore',
    color='Inquinante',

    )

nearest = alt.selection(type='single', nearest=True, on='mouseover',
                        fields=['Data'], empty='none')

line = alt.Chart(dfStazioneDaily).mark_line(interpolate='basis').encode(
    x='Data',
    y='Valore',
    color='Inquinante'
)

selectors = alt.Chart(dfStazioneDaily).mark_point().encode(
    x='Data',
    opacity=alt.value(0),
).add_selection(
    nearest
)

points = line.mark_point().encode(
    opacity=alt.condition(nearest, alt.value(1), alt.value(0))
)

text = line.mark_text(align='left', dx=5, dy=-5).encode(
    text=alt.condition(nearest, 'Valore', alt.value(' '))
)

rules = alt.Chart(dfStazioneDaily).mark_rule(color='gray').encode(
    x='Data'
).transform_filter(
    nearest
)


alt.layer(
    line, selectors, points, rules, text, alt.x()
).properties(
    width=600, height=300
).tickCount(
)
# Out:
# /tmp/ipykernel_47710/2941787461.py:18: DtypeWarning:
#
# Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#
# /tmp/ipykernel_47710/2941787461.py:20: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /tmp/ipykernel_47710/2941787461.py:21: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/davide/Desktop/Git/webvalley-dashboard/Davide1.ipynb Cell 5 in <cell line: 70>()
#      <a href='vscode-notebook-cell:/home/davide/Desktop/Git/webvalley-dashboard/Davide1.ipynb#ch0000007?line=61'>62</a> rules = alt.Chart(dfStazioneDaily).mark_rule(color='gray').encode(
#      <a href='vscode-notebook-cell:/home/davide/Desktop/Git/webvalley-dashboard/Davide1.ipynb#ch0000007?line=62'>63</a>     x='Data'
#      <a href='vscode-notebook-cell:/home/davide/Desktop/Git/webvalley-dashboard/Davide1.ipynb#ch0000007?line=63'>64</a> ).transform_filter(
#      <a href='vscode-notebook-cell:/home/davide/Desktop/Git/webvalley-dashboard/Davide1.ipynb#ch0000007?line=64'>65</a>     nearest
#      <a href='vscode-notebook-cell:/home/davide/Desktop/Git/webvalley-dashboard/Davide1.ipynb#ch0000007?line=65'>66</a> )
#      <a href='vscode-notebook-cell:/home/davide/Desktop/Git/webvalley-dashboard/Davide1.ipynb#ch0000007?line=67'>68</a> x=alt.X('norm:O', bin=True)
#      <a href='vscode-notebook-cell:/home/davide/Desktop/Git/webvalley-dashboard/Davide1.ipynb#ch0000007?line=69'>70</a> alt.layer(
#      <a href='vscode-notebook-cell:/home/davide/Desktop/Git/webvalley-dashboard/Davide1.ipynb#ch0000007?line=70'>71</a>     line, selectors, points, rules, text
#      <a href='vscode-notebook-cell:/home/davide/Desktop/Git/webvalley-dashboard/Davide1.ipynb#ch0000007?line=71'>72</a> ).properties(
#      <a href='vscode-notebook-cell:/home/davide/Desktop/Git/webvalley-dashboard/Davide1.ipynb#ch0000007?line=72'>73</a>     width=600, height=300
# ---> <a href='vscode-notebook-cell:/home/davide/Desktop/Git/webvalley-dashboard/Davide1.ipynb#ch0000007?line=73'>74</a> ).tickCount(
#      <a href='vscode-notebook-cell:/home/davide/Desktop/Git/webvalley-dashboard/Davide1.ipynb#ch0000007?line=74'>75</a> )
#
# File ~/.local/lib/python3.10/site-packages/altair/utils/schemapi.py:258, in SchemaBase.__getattr__(self, attr)
#     256 except AttributeError:
#     257     _getattr = super(SchemaBase, self).__getattribute__
# --> 258 return _getattr(attr)
#
# AttributeError: 'LayerChart' object has no attribute 'tickCount'
